# %% [markdown]
# > Arnob Dey |
# > ID : 203-15-3906|
# > Section : PC - B |
# > Subject: Artificial Intelligence Lab |
# > Course Code: CSE316 |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Using same dataset from Aditi Dhali ma'ams class
data = pd.read_csv("https://raw.githubusercontent.com/Avik-Jain/100-Days-Of-ML-Code/master/datasets/50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
print(data['Profit'].head())
plt.hist(data['Profit'])
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64
# (array([ 1.,  3.,  2.,  6., 10.,  8.,  7.,  7.,  2.,  4.]),
#  array([ 14681.4  ,  32439.443,  50197.486,  67955.529,  85713.572,
#         103471.615, 121229.658, 138987.701, 156745.744, 174503.787,
#         192261.83 ]),
#  <a list of 10 Patch objects>)

# %%
#Add a column named total spent by adding R&D, Administration and Marketing

# %%
sns.pairplot(data)

# %%
data.head()
sns.pairplot(data, hue="Profit")

# %%
data.head()

sns.pairplot(data, hue="State", palette="Set1", diag_kind="kde", markers=["o", "s", "D"], kind="reg", corner=True, height=3)

# %%
sns.pairplot(data, hue="Profit", palette="Set1")

# %%
data.head()

sns.pairplot(data, hue="State", palette="Set1", diag_kind="kde")

# %%
sns.pairplot(data, hue="State", palette="Set1", diag_kind="kde", markers=["o", "s", "D"])

# %%
data.head()

sns.pairplot(data, hue="State", palette="Set1", diag_kind="kde", markers=["o", "s", "D"], kind="reg")

# %%
data.head()

sns.pairplot(data, hue="State", palette="Set1", diag_kind="kde", markers=["o", "s", "D"], kind="reg", corner=True)
